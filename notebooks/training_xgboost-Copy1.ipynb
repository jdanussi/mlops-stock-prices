# %%
import json
import pickle
import os

import numpy as np
import pandas as pd
from sqlalchemy import create_engine

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb

from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from hyperopt.pyll import scope

import yfinance as yf

# %%
# Dump to pickle
def dump_pickle(obj, filename: str):
    with open(filename, "wb") as f_out:
        return pickle.dump(obj, f_out)


# Load from pickle
def load_pickle(filename: str):
    with open(filename, "rb") as f_in:
        return pickle.load(f_in)


# Download stock price data
def download_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data


# Preprocess data and create input sequences
def preprocess_data(data, sequence_length):
    sequences = []
    data = data.reset_index()
    adj_close = data['Adj Close']
    date = data['Date']
    
    for i in range(len(adj_close) - sequence_length):
        adj_close_sequence = adj_close.iloc[i:i+sequence_length+1].values
        target_date = date.iloc[i+sequence_length]
        sequence = np.append(target_date, adj_close_sequence)
        sequences.append(sequence)

    return sequences


# Split data into training and testing sets
def split_data(data, test_size=0.2):
    train_data, test_data = train_test_split(data, test_size=test_size, shuffle=False)
    return train_data, test_data


# Hyperparameter tuning
def run_optimization(X_train, y_train, X_test, y_test, num_trials: int = 30):
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_test, label=y_test)

    def objective(params):
        model = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = model.predict(valid)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        return {'loss': rmse, 'status': STATUS_OK}    
    
    search_space = {
        'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
        'learning_rate': hp.loguniform('learning_rate', -3, 0),
        'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
        'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
        'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
        'objective': 'reg:linear',
        'seed': 42
    }

    rstate = np.random.default_rng(42)  # for reproducible results
    best_params = fmin(
        fn=objective,
        space=search_space,
        algo=tpe.suggest,
        max_evals=num_trials,
        trials=Trials(),
        rstate=rstate
    )
    return best_params


# Train XGBoost regression model
def train_model(X_train, y_train, X_test, y_test, best_params):
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_test, label=y_test)
    
    best_params['max_depth']=int(best_params['max_depth'])

    model = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50,
    )
    return model


# Evaluate model on test data
def evaluate_model(model, X_test, y_test):
    valid = xgb.DMatrix(X_test, label=y_test)
    
    predictions = model.predict(valid)
    mse = mean_squared_error(y_test, predictions)
    rmse = mean_squared_error(y_test, predictions, squared=False)
    return mse, rmse


# Make predictions
def predict_model(model, data):
    valid = xgb.DMatrix(data)
    predictions = model.predict(valid)
    return predictions

# %%
# Generate the test.json for pytest with the goog stock data from 2024-01-02
ticker = 'goog'
start_date = '2024-01-02'
end_date = '2024-01-03'

stock_data = download_stock_data(ticker, start_date, end_date)
stock_data.reset_index(inplace=True)
stock_data['Date'] = stock_data['Date'].astype(str)
stock_data.to_json('test.json', orient = 'records')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Download stock data
# amzn / goog / msft
ticker = 'goog'
start_date = '2024-01-02'
end_date = '2024-10-01'

stock_data = download_stock_data(ticker, start_date, end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df = (
    pd.DataFrame(stock_data)
    .reset_index()
    .rename(
        columns={
            "Date": "date",
            "Open": "open",
            "High": "high",
            "Low": "low",
            "Close": "close",
            "Adj Close": "adj_close",
            "Volume": "volume",
        }
    )
)
df["symbol"] = ticker
df = df[["date", "symbol", "open", "high", "low", "close", "adj_close", "volume"]]

# %%
# Display the DataFrame
df.head()
# Out:
#         date symbol        open        high         low       close  \
# 0 2024-01-02   goog  139.600006  140.615005  137.740005  139.559998
# 1 2024-01-03   goog  138.600006  141.089996  138.429993  140.360001
# 2 2024-01-04   goog  139.850006  140.634995  138.009995  138.039993
# 3 2024-01-05   goog  138.352005  138.809998  136.850006  137.389999
# 4 2024-01-08   goog  138.000000  140.639999  137.880005  140.529999
#
#     adj_close    volume
# 0  139.218109  20071900
# 1  140.016144  18974300
# 2  137.701828  18253300
# 3  137.053421  15433200
# 4  140.185715  17645300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       188 non-null    datetime64[ns]
#  1   symbol     188 non-null    object
#  2   open       188 non-null    float64
#  3   high       188 non-null    float64
#  4   low        188 non-null    float64
#  5   close      188 non-null    float64
#  6   adj_close  188 non-null    float64
#  7   volume     188 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 11.9+ KB

# %%
# Save historical data to csv.
df.to_csv(f'stocks_{ticker}_{start_date}_to_{end_date}.csv')

# %%
# Create connection to postgres instance
db_uri = 'postgresql://airflow:albeta2023@mlops-rds-instance.crcqa0ua6cb3.us-east-1.rds.amazonaws.com:5432/stocks'
engine = create_engine(db_uri)

# %%
# Insert historical data into postgres table 'stock_ohlc'
df.to_sql('stock_ohlc', con=engine, if_exists='append', index=False)
# Out:
# 188

# %%
stock_data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2024-01-02  139.600006  140.615005  137.740005  139.559998  139.401367
#
#      Volume
# 0  20071900

# %%
# Preprocess data
# For every date, build the close price sequence of 10 consecutive days
# Each sequence is conform by 'Date' + last 10 close prices + 'Adj Close'
sequence_length = 10
data_sequences = preprocess_data(stock_data, sequence_length)
data_sequences[-2:]
# Out:
# [array([Timestamp('2024-06-27 00:00:00'), 179.55999755859375,
#         176.74000549316406, 178.3699951171875, 178.77999877929688,
#         176.4499969482422, 177.7100067138672, 180.25999450683594,
#         180.7899932861328, 185.5800018310547, 185.3699951171875,
#         186.86000061035156], dtype=object),
#  array([Timestamp('2024-06-28 00:00:00'), 176.74000549316406,
#         178.3699951171875, 178.77999877929688, 176.4499969482422,
#         177.7100067138672, 180.25999450683594, 180.7899932861328,
#         185.5800018310547, 185.3699951171875, 186.86000061035156,
#         183.4199981689453], dtype=object)]

# %%
# Create pandas dataframe from the sequences
data_sequences_df = pd.DataFrame(data=data_sequences, columns=['date','d10','d9','d8','d7','d6','d5','d4','d3','d2','d1','adj_close']) 
data_sequences_df.head()
# Out:
#         date         d10          d9          d8          d7          d6  \
# 0 2024-01-17  139.401367  140.200455  137.883087  137.233841  140.370270
# 1 2024-01-18  140.200455  137.883087  137.233841  140.370270  142.397949
# 2 2024-01-19  137.883087  137.233841  140.370270  142.397949  143.636551
# 3 2024-01-22  137.233841  140.370270  142.397949  143.636551  143.506699
# 4 2024-01-23  140.370270  142.397949  143.636551  143.506699  144.076050
#
#            d5          d4          d3          d2          d1   adj_close
# 0  142.397949  143.636551  143.506699  144.076050  143.916229  142.727585
# 1  143.636551  143.506699  144.076050  143.916229  142.727585  144.825195
# 2  143.506699  144.076050  143.916229  142.727585  144.825195  147.801804
# 3  144.076050  143.916229  142.727585  144.825195  147.801804  147.542114
# 4  143.916229  142.727585  144.825195  147.801804  147.542114  148.511002

# %%
# Split data into training and testing sets
train_data, test_data = split_data(data_sequences_df)

# %%
train_data.describe()
# Out:
#                                 date         d10          d9          d8  \
# count                             91   91.000000   91.000000   91.000000
# mean   2024-03-21 15:33:37.582417664  149.893933  150.237937  150.584466
# min              2024-01-17 00:00:00  132.409317  132.409317  132.409317
# 25%              2024-02-18 00:00:00  142.472870  142.637688  143.052208
# 50%              2024-03-21 00:00:00  148.311218  148.511002  148.560944
# 75%              2024-04-23 12:00:00  156.172287  156.257187  156.511902
# max              2024-05-24 00:00:00  173.492569  173.492569  173.492569
# std                              NaN   10.028395   10.199920   10.389032
#
#                d7          d6          d5          d4          d3          d2  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000   91.000000
# mean   150.977864  151.395411  151.798908  152.192965  152.585266  152.962090
# min    132.409317  132.409317  132.409317  132.409317  132.409317  132.409317
# 25%    143.441765  143.571625  143.656525  143.726448  143.846313  143.996140
# 50%    148.570938  149.509857  150.049255  150.179108  150.978195  151.527573
# 75%    156.991356  157.380913  157.625633  157.770462  157.865356  158.484657
# max    173.682358  175.230591  177.088470  178.257156  179.335922  179.335922
# std     10.578796   10.778278   11.044948   11.341521   11.655343   11.910105
#
#                d1   adj_close
# count   91.000000   91.000000
# mean   153.300386  153.654379
# min    132.409317  132.409317
# 25%    144.046082  144.470596
# 50%    151.597488  151.767303
# 75%    159.373642  160.172722
# max    179.335922  179.335922
# std     12.090741   12.282982

# %%
test_data.describe()
# Out:
#                                 date         d10          d9          d8  \
# count                             23   23.000000   23.000000   23.000000
# mean   2024-06-12 09:23:28.695652096  176.000120  176.333349  176.639672
# min              2024-05-28 00:00:00  170.705734  171.734573  173.362717
# 25%              2024-06-04 12:00:00  174.541374  174.895973  175.080765
# 50%              2024-06-12 00:00:00  176.630005  176.740005  176.868744
# 75%              2024-06-20 12:00:00  177.807663  177.982468  178.168640
# max              2024-06-28 00:00:00  179.559998  179.559998  179.559998
# std                              NaN    2.325649    2.067299    1.867195
#
#                d7          d6          d5          d4          d3          d2  \
# count   23.000000   23.000000   23.000000   23.000000   23.000000   23.000000
# mean   176.760004  176.867804  177.005697  177.115820  177.387302  177.716533
# min    173.362717  173.362717  173.362717  173.362717  173.362717  173.362717
# 25%    175.490295  175.939789  175.939789  175.939789  175.939789  175.939789
# 50%    176.868744  177.088470  177.198349  177.198349  177.198349  177.198349
# 75%    178.168640  178.168640  178.223579  178.279999  178.279999  178.574997
# max    179.559998  179.559998  180.259995  180.789993  185.580002  185.580002
# std      1.753676    1.731454    1.870530    2.016424    2.649782    3.129998
#
#                d1   adj_close
# count   23.000000   23.000000
# mean   178.238229  178.555204
# min    173.362717  173.362717
# 25%    176.289787  176.540001
# 50%    177.710007  177.817657
# 75%    179.169998  179.909996
# max    186.860001  186.860001
# std      3.597478    3.722256

# %%
# Setup numerical features and the target (there are no categorical features)
num_features = ['d10','d9','d8','d7','d6','d5','d4','d3','d2','d1']
target = ['adj_close']

# %%
# Prepare training data
X_train = train_data[num_features]
y_train = train_data[target]

# Prepare test data
X_test = test_data[num_features]
y_test = test_data[target]

# %%
dump_pickle((X_train, y_train), "train_goog.pkl")
dump_pickle((X_test, y_test), "test_goog.pkl")

# %%
# Find best_params for XGBoost
best_params = run_optimization(X_train, y_train, X_test, y_test)
# Out:
# [0]	validation-rmse:15.31032
# [1]	validation-rmse:10.61778
# [2]	validation-rmse:8.12751
# [3]	validation-rmse:7.03434
# [4]	validation-rmse:6.18613
#   0%|          | 0/30 [00:00<?, ?trial/s, best loss=?]
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [21:06:56] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [5]	validation-rmse:5.64713
# [6]	validation-rmse:5.35651
# [7]	validation-rmse:5.45521
# [8]	validation-rmse:5.51340
# [9]	validation-rmse:5.31227
# [10]	validation-rmse:5.21957
# [11]	validation-rmse:5.31525
# [12]	validation-rmse:5.37918
# [13]	validation-rmse:5.45131
# [14]	validation-rmse:5.29302
# [15]	validation-rmse:5.20689
# [16]	validation-rmse:5.32144
# [17]	validation-rmse:5.21815
# [18]	validation-rmse:5.30336
# [19]	validation-rmse:5.21216
# [20]	validation-rmse:5.26786
# [21]	validation-rmse:5.18847
# [22]	validation-rmse:5.15024
# [23]	validation-rmse:5.23693
# [24]	validation-rmse:5.17318
# [25]	validation-rmse:5.24004
# [26]	validation-rmse:5.27741
# [27]	validation-rmse:5.19258
# [28]	validation-rmse:5.13776
# [29]	validation-rmse:5.20041
# [30]	validation-rmse:5.13844
# [31]	validation-rmse:5.18047
# [32]	validation-rmse:5.11646
# [33]	validation-rmse:5.16804
# [34]	validation-rmse:5.14362
# [35]	validation-rmse:5.18638
# [36]	validation-rmse:5.12512
# [37]	validation-rmse:5.16754
# [38]	validation-rmse:5.10980
# [39]	validation-rmse:5.14677
# [40]	validation-rmse:5.08908
# [41]	validation-rmse:5.12562
# [42]	validation-rmse:5.07588
# [43]	validation-rmse:5.11204
# [44]	validation-rmse:5.06429
# [45]	validation-rmse:5.10103
# [46]	validation-rmse:5.05488
# [47]	validation-rmse:5.08732
# [48]	validation-rmse:5.04144
# [49]	validation-rmse:5.07327
# [50]	validation-rmse:5.03404
# [51]	validation-rmse:5.06651
# [52]	validation-rmse:5.02859
# [53]	validation-rmse:5.05997
# [54]	validation-rmse:5.02912
# [55]	validation-rmse:5.05916
# [56]	validation-rmse:5.01966
# [57]	validation-rmse:5.04919
# [58]	validation-rmse:5.01500
# [59]	validation-rmse:5.04206
# [60]	validation-rmse:5.00316
# [61]	validation-rmse:5.03070
# [62]	validation-rmse:4.99798
# [63]	validation-rmse:5.02529
# [64]	validation-rmse:4.99448
# [65]	validation-rmse:5.02163
# [66]	validation-rmse:4.98917
# [67]	validation-rmse:5.01206
# [68]	validation-rmse:4.97945
# [69]	validation-rmse:4.96254
# [70]	validation-rmse:4.99260
# [71]	validation-rmse:4.96697
# [72]	validation-rmse:4.99323
# [73]	validation-rmse:4.96817
# [74]	validation-rmse:4.99011
# [75]	validation-rmse:4.96134
# [76]	validation-rmse:4.98389
# [77]	validation-rmse:4.95821
# [78]	validation-rmse:4.98030
# [79]	validation-rmse:4.95586
# [80]	validation-rmse:4.97583
# [81]	validation-rmse:4.94985
# [82]	validation-rmse:4.96853
# [83]	validation-rmse:4.94501
# [84]	validation-rmse:4.96392
# [85]	validation-rmse:4.94007
# [86]	validation-rmse:4.95957
# [87]	validation-rmse:4.93787
# [88]	validation-rmse:4.92470
# [89]	validation-rmse:4.94924
# [90]	validation-rmse:4.96371
# [91]	validation-rmse:4.93936
# [92]	validation-rmse:4.92301
# [93]	validation-rmse:4.94174
# [94]	validation-rmse:4.92781
# [95]	validation-rmse:4.94567
# [96]	validation-rmse:4.92594
# [97]	validation-rmse:4.94173
# [98]	validation-rmse:4.92228
# [99]	validation-rmse:4.93806
# [100]	validation-rmse:4.91867
# [101]	validation-rmse:4.93442
# [102]	validation-rmse:4.91683
# [103]	validation-rmse:4.93223
# [104]	validation-rmse:4.91539
# [105]	validation-rmse:4.92932
# [106]	validation-rmse:4.91133
# [107]	validation-rmse:4.92525
# [108]	validation-rmse:4.90927
# [109]	validation-rmse:4.90029
# [110]	validation-rmse:4.91778
# [111]	validation-rmse:4.90455
# [112]	validation-rmse:4.91864
# [113]	validation-rmse:4.90308
# [114]	validation-rmse:4.91541
# [115]	validation-rmse:4.90066
# [116]	validation-rmse:4.91219
# [117]	validation-rmse:4.89726
# [118]	validation-rmse:4.90945
# [119]	validation-rmse:4.89588
# [120]	validation-rmse:4.90769
# [121]	validation-rmse:4.89389
# [122]	validation-rmse:4.90425
# [123]	validation-rmse:4.89067
# [124]	validation-rmse:4.90156
# [125]	validation-rmse:4.88925
# [126]	validation-rmse:4.89851
# [127]	validation-rmse:4.88477
# [128]	validation-rmse:4.89496
# [129]	validation-rmse:4.88319
# [130]	validation-rmse:4.89327
# [131]	validation-rmse:4.88234
# [132]	validation-rmse:4.89197
# [133]	validation-rmse:4.88094
# [134]	validation-rmse:4.89005
# [135]	validation-rmse:4.87899
# [136]	validation-rmse:4.87261
# [137]	validation-rmse:4.88431
# [138]	validation-rmse:4.87530
# [139]	validation-rmse:4.88432
# [140]	validation-rmse:4.87411
# [141]	validation-rmse:4.88315
# [142]	validation-rmse:4.87387
# [143]	validation-rmse:4.88156
# [144]	validation-rmse:4.87108
# [145]	validation-rmse:4.87894
# [146]	validation-rmse:4.87049
# [147]	validation-rmse:4.87863
# [148]	validation-rmse:4.86979
# [149]	validation-rmse:4.87682
# [150]	validation-rmse:4.86718
# [151]	validation-rmse:4.87374
# [152]	validation-rmse:4.86516
# [153]	validation-rmse:4.86026
# [154]	validation-rmse:4.86867
# [155]	validation-rmse:4.86110
# [156]	validation-rmse:4.86870
# [157]	validation-rmse:4.86112
# [158]	validation-rmse:4.86812
# [159]	validation-rmse:4.86082
# [160]	validation-rmse:4.86752
# [161]	validation-rmse:4.85999
# [162]	validation-rmse:4.86573
# [163]	validation-rmse:4.85823
# [164]	validation-rmse:4.86421
# [165]	validation-rmse:4.85746
# [166]	validation-rmse:4.85313
# [167]	validation-rmse:4.86064
# [168]	validation-rmse:4.85515
# [169]	validation-rmse:4.86125
# [170]	validation-rmse:4.85480
# [171]	validation-rmse:4.86044
# [172]	validation-rmse:4.85428
# [173]	validation-rmse:4.85928
# [174]	validation-rmse:4.85275
# [175]	validation-rmse:4.85751
# [176]	validation-rmse:4.85166
# [177]	validation-rmse:4.84840
# [178]	validation-rmse:4.85467
# [179]	validation-rmse:4.84982
# [180]	validation-rmse:4.85485
# [181]	validation-rmse:4.84914
# [182]	validation-rmse:4.85384
# [183]	validation-rmse:4.84864
# [184]	validation-rmse:4.85319
# [185]	validation-rmse:4.84807
# [186]	validation-rmse:4.84587
# [187]	validation-rmse:4.85117
# [188]	validation-rmse:4.84643
# [189]	validation-rmse:4.85090
# [190]	validation-rmse:4.84630
# [191]	validation-rmse:4.85044
# [192]	validation-rmse:4.84568
# [193]	validation-rmse:4.84949
# [194]	validation-rmse:4.84470
# [195]	validation-rmse:4.84844
# [196]	validation-rmse:4.84415
# [197]	validation-rmse:4.84771
# [198]	validation-rmse:4.84316
# [199]	validation-rmse:4.84670
# [200]	validation-rmse:4.84264
# [201]	validation-rmse:4.84042
# [202]	validation-rmse:4.84480
# [203]	validation-rmse:4.84145
# [204]	validation-rmse:4.84507
# [205]	validation-rmse:4.84100
# [206]	validation-rmse:4.84397
# [207]	validation-rmse:4.83996
# [208]	validation-rmse:4.83735
# [209]	validation-rmse:4.84136
# [210]	validation-rmse:4.83821
# [211]	validation-rmse:4.84147
# [212]	validation-rmse:4.83827
# [213]	validation-rmse:4.84108
# [214]	validation-rmse:4.84294
# [215]	validation-rmse:4.83888
# [216]	validation-rmse:4.83610
# [217]	validation-rmse:4.83896
# [218]	validation-rmse:4.83610
# [219]	validation-rmse:4.83862
# [220]	validation-rmse:4.83548
# [221]	validation-rmse:4.83812
# [222]	validation-rmse:4.83605
# [223]	validation-rmse:4.83829
# [224]	validation-rmse:4.83531
# [225]	validation-rmse:4.83315
# [226]	validation-rmse:4.83627
# [227]	validation-rmse:4.83785
# [228]	validation-rmse:4.83470
# [229]	validation-rmse:4.83689
# [230]	validation-rmse:4.83399
# [231]	validation-rmse:4.83587
# [232]	validation-rmse:4.83314
# [233]	validation-rmse:4.83529
# [234]	validation-rmse:4.83285
# [235]	validation-rmse:4.83162
# [236]	validation-rmse:4.83419
# [237]	validation-rmse:4.83563
# [238]	validation-rmse:4.83299
# [239]	validation-rmse:4.83094
# [240]	validation-rmse:4.83308
# [241]	validation-rmse:4.83440
# [242]	validation-rmse:4.83187
# [243]	validation-rmse:4.83359
# [244]	validation-rmse:4.83131
# [245]	validation-rmse:4.83022
# [246]	validation-rmse:4.83224
# [247]	validation-rmse:4.83020
# [248]	validation-rmse:4.83202
# [249]	validation-rmse:4.83009
# [250]	validation-rmse:4.83180
# [251]	validation-rmse:4.82998
# [252]	validation-rmse:4.83159
# [253]	validation-rmse:4.82968
# [254]	validation-rmse:4.83111
# [255]	validation-rmse:4.82923
# [256]	validation-rmse:4.83069
# [257]	validation-rmse:4.82899
# [258]	validation-rmse:4.83024
# [259]	validation-rmse:4.82832
# [260]	validation-rmse:4.82759
# [261]	validation-rmse:4.82920
# [262]	validation-rmse:4.82787
# [263]	validation-rmse:4.82933
# [264]	validation-rmse:4.82782
# [265]	validation-rmse:4.82905
# [266]	validation-rmse:4.82750
# [267]	validation-rmse:4.82686
# [268]	validation-rmse:4.82830
# [269]	validation-rmse:4.82703
# [270]	validation-rmse:4.82820
# [271]	validation-rmse:4.82676
# [272]	validation-rmse:4.82796
# [273]	validation-rmse:4.82664
# [274]	validation-rmse:4.82777
# [275]	validation-rmse:4.82642
# [276]	validation-rmse:4.82548
# [277]	validation-rmse:4.82679
# [278]	validation-rmse:4.82615
# [279]	validation-rmse:4.82710
# [280]	validation-rmse:4.82589
# [281]	validation-rmse:4.82691
# [282]	validation-rmse:4.82573
# [283]	validation-rmse:4.82661
# [284]	validation-rmse:4.82541
# [285]	validation-rmse:4.82634
# [286]	validation-rmse:4.82527
# [287]	validation-rmse:4.82481
# [288]	validation-rmse:4.82584
# [289]	validation-rmse:4.82649
# [290]	validation-rmse:4.82529
# [291]	validation-rmse:4.82602
# [292]	validation-rmse:4.82490
# [293]	validation-rmse:4.82567
# [294]	validation-rmse:4.82606
# [295]	validation-rmse:4.82488
# [296]	validation-rmse:4.82545
# [297]	validation-rmse:4.82432
# [298]	validation-rmse:4.82365
# [299]	validation-rmse:4.82323
# [300]	validation-rmse:4.82426
# [301]	validation-rmse:4.82357
# [302]	validation-rmse:4.82441
# [303]	validation-rmse:4.82488
# [304]	validation-rmse:4.82390
# [305]	validation-rmse:4.82352
# [306]	validation-rmse:4.82426
# [307]	validation-rmse:4.82352
# [308]	validation-rmse:4.82326
# [309]	validation-rmse:4.82398
# [310]	validation-rmse:4.82437
# [311]	validation-rmse:4.82347
# [312]	validation-rmse:4.82404
# [313]	validation-rmse:4.82330
# [314]	validation-rmse:4.82388
# [315]	validation-rmse:4.82417
# [316]	validation-rmse:4.82330
# [317]	validation-rmse:4.82274
# [318]	validation-rmse:4.82336
# [319]	validation-rmse:4.82369
# [320]	validation-rmse:4.82294
# [321]	validation-rmse:4.82241
# [322]	validation-rmse:4.82216
# [323]	validation-rmse:4.82285
# [324]	validation-rmse:4.82322
# [325]	validation-rmse:4.82347
# [326]	validation-rmse:4.82270
# [327]	validation-rmse:4.82223
# [328]	validation-rmse:4.82190
# [329]	validation-rmse:4.82250
# [330]	validation-rmse:4.82280
# [331]	validation-rmse:4.82219
# [332]	validation-rmse:4.82259
# [333]	validation-rmse:4.82281
# [334]	validation-rmse:4.82222
# [335]	validation-rmse:4.82175
# [336]	validation-rmse:4.82212
# [337]	validation-rmse:4.82236
# [338]	validation-rmse:4.82185
# [339]	validation-rmse:4.82220
# [340]	validation-rmse:4.82171
# [341]	validation-rmse:4.82201
# [342]	validation-rmse:4.82221
# [343]	validation-rmse:4.82171
# [344]	validation-rmse:4.82194
# [345]	validation-rmse:4.82205
# [346]	validation-rmse:4.82158
# [347]	validation-rmse:4.82190
# [348]	validation-rmse:4.82145
# [349]	validation-rmse:4.82166
# [350]	validation-rmse:4.82123
# [351]	validation-rmse:4.82155
# [352]	validation-rmse:4.82173
# [353]	validation-rmse:4.82130
# [354]	validation-rmse:4.82093
# [355]	validation-rmse:4.82122
# [356]	validation-rmse:4.82100
# [357]	validation-rmse:4.82119
# [358]	validation-rmse:4.82084
# [359]	validation-rmse:4.82110
# [360]	validation-rmse:4.82126
# [361]	validation-rmse:4.82091
# [362]	validation-rmse:4.82114
# [363]	validation-rmse:4.82089
# [364]	validation-rmse:4.82098
# [365]	validation-rmse:4.82111
# [366]	validation-rmse:4.82078
# [367]	validation-rmse:4.82048
# [368]	validation-rmse:4.82035
# [369]	validation-rmse:4.82063
# [370]	validation-rmse:4.82076
# [371]	validation-rmse:4.82047
# [372]	validation-rmse:4.82065
# [373]	validation-rmse:4.82073
# [374]	validation-rmse:4.82057
# [375]	validation-rmse:4.82067
# [376]	validation-rmse:4.82045
# [377]	validation-rmse:4.82021
# [378]	validation-rmse:4.82038
# [379]	validation-rmse:4.82047
# [380]	validation-rmse:4.82022
# [381]	validation-rmse:4.82035
# [382]	validation-rmse:4.82015
# [383]	validation-rmse:4.82026
# [384]	validation-rmse:4.82012
# [385]	validation-rmse:4.82016
# [386]	validation-rmse:4.82008
# [387]	validation-rmse:4.82017
# [388]	validation-rmse:4.81997
# [389]	validation-rmse:4.82003
# [390]	validation-rmse:4.81990
# [391]	validation-rmse:4.81979
# [392]	validation-rmse:4.81993
# [393]	validation-rmse:4.82000
# [394]	validation-rmse:4.81984
# [395]	validation-rmse:4.81991
# [396]	validation-rmse:4.81986
# [397]	validation-rmse:4.81972
# [398]	validation-rmse:4.81979
# [399]	validation-rmse:4.81977
# [400]	validation-rmse:4.81980
# [401]	validation-rmse:4.81981
# [402]	validation-rmse:4.81973
# [403]	validation-rmse:4.81964
# [404]	validation-rmse:4.81970
# [405]	validation-rmse:4.81957
# [406]	validation-rmse:4.81962
# [407]	validation-rmse:4.81962
# [408]	validation-rmse:4.81962
# [409]	validation-rmse:4.81955
# [410]	validation-rmse:4.81957
# [411]	validation-rmse:4.81947
# [412]	validation-rmse:4.81952
# [413]	validation-rmse:4.81944
# [414]	validation-rmse:4.81948
# [415]	validation-rmse:4.81947
# [416]	validation-rmse:4.81947
# [417]	validation-rmse:4.81940
# [418]	validation-rmse:4.81941
# [419]	validation-rmse:4.81934
# [420]	validation-rmse:4.81936
# [421]	validation-rmse:4.81931
# [422]	validation-rmse:4.81932
# [423]	validation-rmse:4.81932
# [424]	validation-rmse:4.81932
# [425]	validation-rmse:4.81932
# [426]	validation-rmse:4.81932
# [427]	validation-rmse:4.81927
# [428]	validation-rmse:4.81927
# [429]	validation-rmse:4.81924
# [430]	validation-rmse:4.81924
# [431]	validation-rmse:4.81920
# [432]	validation-rmse:4.81920
# [433]	validation-rmse:4.81920
# [434]	validation-rmse:4.81920
# [435]	validation-rmse:4.81916
# [436]	validation-rmse:4.81916
# [437]	validation-rmse:4.81911
# [438]	validation-rmse:4.81911
# [439]	validation-rmse:4.81911
# [440]	validation-rmse:4.81909
# [441]	validation-rmse:4.81909
# [442]	validation-rmse:4.81907
# [443]	validation-rmse:4.81907
# [444]	validation-rmse:4.81907
# [445]	validation-rmse:4.81905
# [446]	validation-rmse:4.81905
# [447]	validation-rmse:4.81905
# [448]	validation-rmse:4.81904
# [449]	validation-rmse:4.81904
# [450]	validation-rmse:4.81904
# [451]	validation-rmse:4.81904
# [452]	validation-rmse:4.81904
# [453]	validation-rmse:4.81904
# [454]	validation-rmse:4.81902
# [455]	validation-rmse:4.81902
# [456]	validation-rmse:4.81898
# [457]	validation-rmse:4.81898
# [458]	validation-rmse:4.81894
# [459]	validation-rmse:4.81894
# [460]	validation-rmse:4.81888
# [461]	validation-rmse:4.81888
# [462]	validation-rmse:4.81885
# [463]	validation-rmse:4.81885
# [464]	validation-rmse:4.81885
# [465]	validation-rmse:4.81885
# [466]	validation-rmse:4.81885
# [467]	validation-rmse:4.81885
# [468]	validation-rmse:4.81880
# [469]	validation-rmse:4.81880
# [470]	validation-rmse:4.81880
# [471]	validation-rmse:4.81874
# [472]	validation-rmse:4.81874
# [473]	validation-rmse:4.81867
# [474]	validation-rmse:4.81867
# [475]	validation-rmse:4.81867
# [476]	validation-rmse:4.81867
# [477]	validation-rmse:4.81861
# [478]	validation-rmse:4.81861
# [479]	validation-rmse:4.81861
# [480]	validation-rmse:4.81861
# [481]	validation-rmse:4.81858
# [482]	validation-rmse:4.81858
# [483]	validation-rmse:4.81856
# [484]	validation-rmse:4.81856
# [485]	validation-rmse:4.81851
# [486]	validation-rmse:4.81851
# [487]	validation-rmse:4.81848
# [488]	validation-rmse:4.81848
# [489]	validation-rmse:4.81847
# [490]	validation-rmse:4.81847
# [491]	validation-rmse:4.81844
# [492]	validation-rmse:4.81840
# [493]	validation-rmse:4.81840
# [494]	validation-rmse:4.81840
# [495]	validation-rmse:4.81840
# [496]	validation-rmse:4.81839
# [497]	validation-rmse:4.81839
# [498]	validation-rmse:4.81837
# [499]	validation-rmse:4.81837
# [500]	validation-rmse:4.81836
# [501]	validation-rmse:4.81836
# [502]	validation-rmse:4.81834
# [503]	validation-rmse:4.81834
# [504]	validation-rmse:4.81833
# [505]	validation-rmse:4.81833
# [506]	validation-rmse:4.81831
# [507]	validation-rmse:4.81831
# [508]	validation-rmse:4.81828
# [509]	validation-rmse:4.81828
# [510]	validation-rmse:4.81826
# [511]	validation-rmse:4.81826
# [512]	validation-rmse:4.81821
# [513]	validation-rmse:4.81821
# [514]	validation-rmse:4.81818
# [515]	validation-rmse:4.81818
# [516]	validation-rmse:4.81815
# [517]	validation-rmse:4.81815
# [518]	validation-rmse:4.81813
# [519]	validation-rmse:4.81813
# [520]	validation-rmse:4.81812
# [521]	validation-rmse:4.81812
# [522]	validation-rmse:4.81810
# [523]	validation-rmse:4.81810
# [524]	validation-rmse:4.81808
# [525]	validation-rmse:4.81808
# [526]	validation-rmse:4.81808
# [527]	validation-rmse:4.81808
# [528]	validation-rmse:4.81808
# [529]	validation-rmse:4.81808
# [530]	validation-rmse:4.81808
# [531]	validation-rmse:4.81808
# [532]	validation-rmse:4.81808
# [533]	validation-rmse:4.81808
# [534]	validation-rmse:4.81808
# [535]	validation-rmse:4.81808
# [536]	validation-rmse:4.81808
# [537]	validation-rmse:4.81808
# [538]	validation-rmse:4.81808
# [539]	validation-rmse:4.81808
# [540]	validation-rmse:4.81808
# [541]	validation-rmse:4.81808
# [542]	validation-rmse:4.81808
# [543]	validation-rmse:4.81808
# [544]	validation-rmse:4.81808
# [545]	validation-rmse:4.81808
# [546]	validation-rmse:4.81808
# [547]	validation-rmse:4.81808
# [548]	validation-rmse:4.81808
# [549]	validation-rmse:4.81808
# [550]	validation-rmse:4.81808
# [551]	validation-rmse:4.81808
# [552]	validation-rmse:4.81808
# [553]	validation-rmse:4.81808
# [554]	validation-rmse:4.81808
# [555]	validation-rmse:4.81808
# [556]	validation-rmse:4.81808
# [557]	validation-rmse:4.81808
# [558]	validation-rmse:4.81808
# [559]	validation-rmse:4.81808
# [560]	validation-rmse:4.81808
# [561]	validation-rmse:4.81808
# [562]	validation-rmse:4.81808
# [563]	validation-rmse:4.81808
# [564]	validation-rmse:4.81808
# [565]	validation-rmse:4.81808
# [566]	validation-rmse:4.81808
# [567]	validation-rmse:4.81808
# [568]	validation-rmse:4.81808
# [569]	validation-rmse:4.81808
# [570]	validation-rmse:4.81808
# [571]	validation-rmse:4.81808
# [572]	validation-rmse:4.81808
# [573]	validation-rmse:4.81808
# [574]	validation-rmse:4.81808
# [0]	validation-rmse:19.83390
#   3%|▎         | 1/30 [00:31<15:16, 31.61s/trial, best loss: 4.818082173712318]
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [21:07:27] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:16.12038
# [2]	validation-rmse:13.37033
# [3]	validation-rmse:11.43581
# [4]	validation-rmse:9.98118
# [5]	validation-rmse:8.69913
# [6]	validation-rmse:7.62577
# [7]	validation-rmse:6.94170
# [8]	validation-rmse:6.36489
# [9]	validation-rmse:5.92992
# [10]	validation-rmse:5.62107
# [11]	validation-rmse:5.37781
# [12]	validation-rmse:5.32636
# [13]	validation-rmse:5.17017
# [14]	validation-rmse:5.16128
# [15]	validation-rmse:5.04105
# [16]	validation-rmse:4.95521
# [17]	validation-rmse:4.97853
# [18]	validation-rmse:4.90574
# [19]	validation-rmse:4.86057
# [20]	validation-rmse:4.88775
# [21]	validation-rmse:4.83596
# [22]	validation-rmse:4.87139
# [23]	validation-rmse:4.90141
# [24]	validation-rmse:4.84757
# [25]	validation-rmse:4.87374
# [26]	validation-rmse:4.81855
# [27]	validation-rmse:4.77880
# [28]	validation-rmse:4.81464
# [29]	validation-rmse:4.84161
# [30]	validation-rmse:4.86344
# [31]	validation-rmse:4.81300
# [32]	validation-rmse:4.83682
# [33]	validation-rmse:4.85569
# [34]	validation-rmse:4.80627
# [35]	validation-rmse:4.76379
# [36]	validation-rmse:4.79088
# [37]	validation-rmse:4.81078
# [38]	validation-rmse:4.76704
# [39]	validation-rmse:4.79256
# [40]	validation-rmse:4.74864
# [41]	validation-rmse:4.72511
# [42]	validation-rmse:4.74219
# [43]	validation-rmse:4.70892
# [44]	validation-rmse:4.73512
# [45]	validation-rmse:4.75202
# [46]	validation-rmse:4.71429
# [47]	validation-rmse:4.68308
# [48]	validation-rmse:4.71037
# [49]	validation-rmse:4.67940
# [50]	validation-rmse:4.70479
# [51]	validation-rmse:4.67476
# [52]	validation-rmse:4.69990
# [53]	validation-rmse:4.67000
# [54]	validation-rmse:4.69228
# [55]	validation-rmse:4.66095
# [56]	validation-rmse:4.64031
# [57]	validation-rmse:4.66659
# [58]	validation-rmse:4.64103
# [59]	validation-rmse:4.66468
# [60]	validation-rmse:4.63795
# [61]	validation-rmse:4.66017
# [62]	validation-rmse:4.63351
# [63]	validation-rmse:4.65539
# [64]	validation-rmse:4.62996
# [65]	validation-rmse:4.61150
# [66]	validation-rmse:4.63707
# [67]	validation-rmse:4.61513
# [68]	validation-rmse:4.63763
# [69]	validation-rmse:4.61221
# [70]	validation-rmse:4.63311
# [71]	validation-rmse:4.60893
# [72]	validation-rmse:4.62959
# [73]	validation-rmse:4.60512
# [74]	validation-rmse:4.58748
# [75]	validation-rmse:4.61134
# [76]	validation-rmse:4.58973
# [77]	validation-rmse:4.61151
# [78]	validation-rmse:4.58894
# [79]	validation-rmse:4.61040
# [80]	validation-rmse:4.59206
# [81]	validation-rmse:4.61165
# [82]	validation-rmse:4.58800
# [83]	validation-rmse:4.60660
# [84]	validation-rmse:4.58444
# [85]	validation-rmse:4.60303
# [86]	validation-rmse:4.57997
# [87]	validation-rmse:4.59866
# [88]	validation-rmse:4.57748
# [89]	validation-rmse:4.59582
# [90]	validation-rmse:4.57367
# [91]	validation-rmse:4.59194
# [92]	validation-rmse:4.57086
# [93]	validation-rmse:4.58884
# [94]	validation-rmse:4.56738
# [95]	validation-rmse:4.58518
# [96]	validation-rmse:4.56499
# [97]	validation-rmse:4.58242
# [98]	validation-rmse:4.56244
# [99]	validation-rmse:4.57960
# [100]	validation-rmse:4.55842
# [101]	validation-rmse:4.57552
# [102]	validation-rmse:4.55492
# [103]	validation-rmse:4.53753
# [104]	validation-rmse:4.55675
# [105]	validation-rmse:4.53815
# [106]	validation-rmse:4.55629
# [107]	validation-rmse:4.53776
# [108]	validation-rmse:4.55509
# [109]	validation-rmse:4.53722
# [110]	validation-rmse:4.55385
# [111]	validation-rmse:4.53701
# [112]	validation-rmse:4.55232
# [113]	validation-rmse:4.53307
# [114]	validation-rmse:4.54907
# [115]	validation-rmse:4.53028
# [116]	validation-rmse:4.54669
# [117]	validation-rmse:4.52848
# [118]	validation-rmse:4.54390
# [119]	validation-rmse:4.52480
# [120]	validation-rmse:4.54009
# [121]	validation-rmse:4.52204
# [122]	validation-rmse:4.53724
# [123]	validation-rmse:4.52012
# [124]	validation-rmse:4.53498
# [125]	validation-rmse:4.51673
# [126]	validation-rmse:4.53217
# [127]	validation-rmse:4.51434
# [128]	validation-rmse:4.52898
# [129]	validation-rmse:4.51226
# [130]	validation-rmse:4.52658
# [131]	validation-rmse:4.50895
# [132]	validation-rmse:4.49403
# [133]	validation-rmse:4.51131
# [134]	validation-rmse:4.49598
# [135]	validation-rmse:4.51197
# [136]	validation-rmse:4.49662
# [137]	validation-rmse:4.51140
# [138]	validation-rmse:4.49494
# [139]	validation-rmse:4.50928
# [140]	validation-rmse:4.49340
# [141]	validation-rmse:4.50742
# [142]	validation-rmse:4.49139
# [143]	validation-rmse:4.50548
# [144]	validation-rmse:4.48963
# [145]	validation-rmse:4.50318
# [146]	validation-rmse:4.48917
# [147]	validation-rmse:4.50192
# [148]	validation-rmse:4.48562
# [149]	validation-rmse:4.49870
# [150]	validation-rmse:4.48366
# [151]	validation-rmse:4.49656
# [152]	validation-rmse:4.48086
# [153]	validation-rmse:4.49370
# [154]	validation-rmse:4.47841
# [155]	validation-rmse:4.49139
# [156]	validation-rmse:4.47657
# [157]	validation-rmse:4.46565
# [158]	validation-rmse:4.48042
# [159]	validation-rmse:4.46687
# [160]	validation-rmse:4.48069
# [161]	validation-rmse:4.46668
# [162]	validation-rmse:4.47929
# [163]	validation-rmse:4.46464
# [164]	validation-rmse:4.47708
# [165]	validation-rmse:4.46266
# [166]	validation-rmse:4.47505
# [167]	validation-rmse:4.46074
# [168]	validation-rmse:4.47284
# [169]	validation-rmse:4.45929
# [170]	validation-rmse:4.47114
# [171]	validation-rmse:4.45703
# [172]	validation-rmse:4.46867
# [173]	validation-rmse:4.45619
# [174]	validation-rmse:4.46736
# [175]	validation-rmse:4.45391
# [176]	validation-rmse:4.46519
# [177]	validation-rmse:4.45122
# [178]	validation-rmse:4.46239
# [179]	validation-rmse:4.44848
# [180]	validation-rmse:4.45992
# [181]	validation-rmse:4.44658
# [182]	validation-rmse:4.45764
# [183]	validation-rmse:4.44487
# [184]	validation-rmse:4.43502
# [185]	validation-rmse:4.44803
# [186]	validation-rmse:4.43672
# [187]	validation-rmse:4.44874
# [188]	validation-rmse:4.43650
# [189]	validation-rmse:4.44750
# [190]	validation-rmse:4.43475
# [191]	validation-rmse:4.44564
# [192]	validation-rmse:4.43305
# [193]	validation-rmse:4.44368
# [194]	validation-rmse:4.43165
# [195]	validation-rmse:4.44209
# [196]	validation-rmse:4.43110
# ...
# [504]	validation-rmse:3.52777
# [505]	validation-rmse:3.52776
# [506]	validation-rmse:3.52776
# [507]	validation-rmse:3.52776
# [508]	validation-rmse:3.52776
# [509]	validation-rmse:3.52776
# [510]	validation-rmse:3.52776
# [511]	validation-rmse:3.52776
# [512]	validation-rmse:3.52776
# [513]	validation-rmse:3.52775
# [514]	validation-rmse:3.52775
# [515]	validation-rmse:3.52775
# [516]	validation-rmse:3.52775
# [517]	validation-rmse:3.52775
# [518]	validation-rmse:3.52775
# [519]	validation-rmse:3.52775
# [520]	validation-rmse:3.52774
# [521]	validation-rmse:3.52774
# [522]	validation-rmse:3.52774
# [523]	validation-rmse:3.52774
# [524]	validation-rmse:3.52774
# [525]	validation-rmse:3.52774
# [526]	validation-rmse:3.52774
# [527]	validation-rmse:3.52774
# [528]	validation-rmse:3.52774
# [529]	validation-rmse:3.52774
# [530]	validation-rmse:3.52773
# [531]	validation-rmse:3.52773
# [532]	validation-rmse:3.52773
# [533]	validation-rmse:3.52773
# [534]	validation-rmse:3.52773
# [535]	validation-rmse:3.52773
# [536]	validation-rmse:3.52773
# [537]	validation-rmse:3.52773
# [538]	validation-rmse:3.52773
# [539]	validation-rmse:3.52773
# [540]	validation-rmse:3.52772
# [541]	validation-rmse:3.52772
# [542]	validation-rmse:3.52772
# [543]	validation-rmse:3.52772
# [544]	validation-rmse:3.52772
# [545]	validation-rmse:3.52772
# [546]	validation-rmse:3.52772
# [547]	validation-rmse:3.52772
# [548]	validation-rmse:3.52772
# [549]	validation-rmse:3.52772
# [550]	validation-rmse:3.52772
# [551]	validation-rmse:3.52772
# [552]	validation-rmse:3.52772
# [553]	validation-rmse:3.52771
# [554]	validation-rmse:3.52771
# [555]	validation-rmse:3.52771
# [556]	validation-rmse:3.52771
# [557]	validation-rmse:3.52771
# [558]	validation-rmse:3.52771
# [559]	validation-rmse:3.52771
# [560]	validation-rmse:3.52771
# [561]	validation-rmse:3.52771
# [562]	validation-rmse:3.52771
# [563]	validation-rmse:3.52771
# [564]	validation-rmse:3.52771
# [565]	validation-rmse:3.52771
# [566]	validation-rmse:3.52771
# [567]	validation-rmse:3.52771
# [568]	validation-rmse:3.52771
# [569]	validation-rmse:3.52771
# [570]	validation-rmse:3.52771
# [571]	validation-rmse:3.52770
# [572]	validation-rmse:3.52770
# [573]	validation-rmse:3.52770
# [574]	validation-rmse:3.52770
# [575]	validation-rmse:3.52770
# [576]	validation-rmse:3.52770
# [577]	validation-rmse:3.52770
# [578]	validation-rmse:3.52770
# [579]	validation-rmse:3.52770
# [580]	validation-rmse:3.52770
# [581]	validation-rmse:3.52770
# [582]	validation-rmse:3.52770
# [583]	validation-rmse:3.52770
# [584]	validation-rmse:3.52770
# [585]	validation-rmse:3.52770
# [586]	validation-rmse:3.52770
# [587]	validation-rmse:3.52770
# [588]	validation-rmse:3.52770
# [589]	validation-rmse:3.52770
# [590]	validation-rmse:3.52770
# [591]	validation-rmse:3.52770
# [592]	validation-rmse:3.52770
# [593]	validation-rmse:3.52770
# [594]	validation-rmse:3.52770
# [595]	validation-rmse:3.52770
# [596]	validation-rmse:3.52770
# [597]	validation-rmse:3.52770
# [598]	validation-rmse:3.52770
# [599]	validation-rmse:3.52770
# [600]	validation-rmse:3.52770
# [601]	validation-rmse:3.52770
# [602]	validation-rmse:3.52770
# [603]	validation-rmse:3.52770
# [604]	validation-rmse:3.52770
# [605]	validation-rmse:3.52770
# [606]	validation-rmse:3.52770
# [607]	validation-rmse:3.52770
# [608]	validation-rmse:3.52770
# [609]	validation-rmse:3.52770
# [610]	validation-rmse:3.52770
# [611]	validation-rmse:3.52770
# [612]	validation-rmse:3.52770
# [613]	validation-rmse:3.52770
# [614]	validation-rmse:3.52770
# [615]	validation-rmse:3.52770
# [616]	validation-rmse:3.52770
# [617]	validation-rmse:3.52770
# [618]	validation-rmse:3.52770
# [619]	validation-rmse:3.52770
# [620]	validation-rmse:3.52770
# [621]	validation-rmse:3.52770
# [622]	validation-rmse:3.52770
# [623]	validation-rmse:3.52770
# [624]	validation-rmse:3.52770
# [625]	validation-rmse:3.52770
# [626]	validation-rmse:3.52770
# [627]	validation-rmse:3.52770
# [628]	validation-rmse:3.52770
# [629]	validation-rmse:3.52770
# [630]	validation-rmse:3.52770
# [631]	validation-rmse:3.52770
# [632]	validation-rmse:3.52770
# [633]	validation-rmse:3.52770
# [634]	validation-rmse:3.52770
# [635]	validation-rmse:3.52770
# [0]	validation-rmse:13.50488
# [1]	validation-rmse:7.90945
#  97%|█████████▋| 29/30 [07:59<00:10, 10.48s/trial, best loss: 3.4426607053682625]
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [21:14:54] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:5.41103
# [3]	validation-rmse:4.44852
# [4]	validation-rmse:4.31447
# [5]	validation-rmse:4.08490
# [6]	validation-rmse:4.14645
# [7]	validation-rmse:4.08228
# [8]	validation-rmse:4.00762
# [9]	validation-rmse:4.07435
# [10]	validation-rmse:4.12324
# [11]	validation-rmse:4.06881
# [12]	validation-rmse:4.12413
# [13]	validation-rmse:4.17444
# [14]	validation-rmse:4.22470
# [15]	validation-rmse:4.26049
# [16]	validation-rmse:4.29497
# [17]	validation-rmse:4.25124
# [18]	validation-rmse:4.28352
# [19]	validation-rmse:4.31779
# [20]	validation-rmse:4.34110
# [21]	validation-rmse:4.30737
# [22]	validation-rmse:4.33674
# [23]	validation-rmse:4.36460
# [24]	validation-rmse:4.38830
# [25]	validation-rmse:4.36312
# [26]	validation-rmse:4.38765
# [27]	validation-rmse:4.41610
# [28]	validation-rmse:4.39670
# [29]	validation-rmse:4.42044
# [30]	validation-rmse:4.44060
# [31]	validation-rmse:4.45983
# [32]	validation-rmse:4.47887
# [33]	validation-rmse:4.49833
# [34]	validation-rmse:4.47986
# [35]	validation-rmse:4.49879
# [36]	validation-rmse:4.51373
# [37]	validation-rmse:4.49536
# [38]	validation-rmse:4.51168
# [39]	validation-rmse:4.53125
# [40]	validation-rmse:4.51936
# [41]	validation-rmse:4.53583
# [42]	validation-rmse:4.55244
# [43]	validation-rmse:4.54047
# [44]	validation-rmse:4.55406
# [45]	validation-rmse:4.56603
# [46]	validation-rmse:4.55682
# [47]	validation-rmse:4.56969
# [48]	validation-rmse:4.58174
# [49]	validation-rmse:4.57268
# [50]	validation-rmse:4.58546
# [51]	validation-rmse:4.59491
# [52]	validation-rmse:4.60406
# [53]	validation-rmse:4.59428
# [54]	validation-rmse:4.60462
# [55]	validation-rmse:4.61434
# [56]	validation-rmse:4.60764
# [57]	validation-rmse:4.61736
# 100%|██████████| 30/30 [08:00<00:00, 16.03s/trial, best loss: 3.4426607053682625]

# %%
# Show best_params
best_params
# Out:
# {'learning_rate': 0.18236672959420272,
#  'max_depth': 11.0,
#  'min_child_weight': 1.2534175878035614,
#  'reg_alpha': 0.02376073607996226,
#  'reg_lambda': 0.3476822703285598}

# %%
# Save best_params to json
with open('hpo_best_params_xgboost.json', 'w') as f:
    json.dump(best_params, f)

# %%
# Train XGBoost regression model with the best_params
loaded_model = train_model(X_train, y_train, X_test, y_test, best_params)
# Out:
# [0]	validation-rmse:21.26888
# [1]	validation-rmse:18.31781
# [2]	validation-rmse:15.57048
# [3]	validation-rmse:13.38032
# [4]	validation-rmse:11.54210
# [5]	validation-rmse:10.16610
# [6]	validation-rmse:8.88506
# [7]	validation-rmse:7.89795
# [8]	validation-rmse:7.36746
# [9]	validation-rmse:6.55371
# [10]	validation-rmse:5.96766
# [11]	validation-rmse:5.69732
# [12]	validation-rmse:5.47492
# [13]	validation-rmse:5.14104
# [14]	validation-rmse:4.84689
# [15]	validation-rmse:4.63373
# [16]	validation-rmse:4.42947
# [17]	validation-rmse:4.29384
# [18]	validation-rmse:4.18033
# [19]	validation-rmse:4.08614
# [20]	validation-rmse:4.00042
# [21]	validation-rmse:3.98092
# [22]	validation-rmse:3.92377
# [23]	validation-rmse:3.87568
# [24]	validation-rmse:3.82950
# [25]	validation-rmse:3.79173
# [26]	validation-rmse:3.74982
# [27]	validation-rmse:3.72033
# [28]	validation-rmse:3.69571
# [29]	validation-rmse:3.67376
# [30]	validation-rmse:3.64447
# [31]	validation-rmse:3.62795
# [32]	validation-rmse:3.60782
# [33]	validation-rmse:3.59472
# [34]	validation-rmse:3.57628
# [35]	validation-rmse:3.56581
# [36]	validation-rmse:3.55681
# [37]	validation-rmse:3.54536
# [38]	validation-rmse:3.53786
# [39]	validation-rmse:3.53140
# [40]	validation-rmse:3.52091
# [41]	validation-rmse:3.51550
# [42]	validation-rmse:3.51081
# [43]	validation-rmse:3.50348
# [44]	validation-rmse:3.49743
# [45]	validation-rmse:3.49410
# [46]	validation-rmse:3.49050
# [47]	validation-rmse:3.48472
# [48]	validation-rmse:3.48261
# [49]	validation-rmse:3.47984
# [50]	validation-rmse:3.47587
# [51]	validation-rmse:3.47417
# [52]	validation-rmse:3.47027
# [53]	validation-rmse:3.46816
# [54]	validation-rmse:3.46474
# [55]	validation-rmse:3.46327
# [56]	validation-rmse:3.46169
# [57]	validation-rmse:3.46169
# [58]	validation-rmse:3.46068
# [59]	validation-rmse:3.45804
# [60]	validation-rmse:3.45696
# [61]	validation-rmse:3.45614
# [62]	validation-rmse:3.45391
# [63]	validation-rmse:3.45302
# [64]	validation-rmse:3.45236
# [65]	validation-rmse:3.45077
# [66]	validation-rmse:3.44991
# [67]	validation-rmse:3.44937
# [68]	validation-rmse:3.44767
# [69]	validation-rmse:3.44707
# [70]	validation-rmse:3.44707
# [71]	validation-rmse:3.44565
# [72]	validation-rmse:3.44593
# [73]	validation-rmse:3.44593
# [74]	validation-rmse:3.44563
# [75]	validation-rmse:3.44457
# [76]	validation-rmse:3.44475
# [77]	validation-rmse:3.44491
# [78]	validation-rmse:3.44407
# [79]	validation-rmse:3.44419
# [80]	validation-rmse:3.44349
# [81]	validation-rmse:3.44360
# [82]	validation-rmse:3.44369
# [83]	validation-rmse:3.44376
# [84]	validation-rmse:3.44328
# [85]	validation-rmse:3.44334
# [86]	validation-rmse:3.44341
# [87]	validation-rmse:3.44346
# [88]	validation-rmse:3.44351
# [89]	validation-rmse:3.44354
# [90]	validation-rmse:3.44322
# [91]	validation-rmse:3.44325
# [92]	validation-rmse:3.44299
# [93]	validation-rmse:3.44301
# [94]	validation-rmse:3.44304
# [95]	validation-rmse:3.44284
# [96]	validation-rmse:3.44266
# [97]	validation-rmse:3.44266
# [98]	validation-rmse:3.44266
# [99]	validation-rmse:3.44266
# [100]	validation-rmse:3.44266
# [101]	validation-rmse:3.44266
# [102]	validation-rmse:3.44266
# [103]	validation-rmse:3.44266
# [104]	validation-rmse:3.44266
# [105]	validation-rmse:3.44266
# [106]	validation-rmse:3.44266
# [107]	validation-rmse:3.44266
# [108]	validation-rmse:3.44266
# [109]	validation-rmse:3.44266
# [110]	validation-rmse:3.44266
# [111]	validation-rmse:3.44266
# [112]	validation-rmse:3.44266
# [113]	validation-rmse:3.44266
# [114]	validation-rmse:3.44266
# [115]	validation-rmse:3.44266
# [116]	validation-rmse:3.44266
# [117]	validation-rmse:3.44266
# [118]	validation-rmse:3.44266
# [119]	validation-rmse:3.44266
# [120]	validation-rmse:3.44266
# [121]	validation-rmse:3.44266
# [122]	validation-rmse:3.44266
# [123]	validation-rmse:3.44266
# [124]	validation-rmse:3.44266
# [125]	validation-rmse:3.44266
# [126]	validation-rmse:3.44266
# [127]	validation-rmse:3.44266
# [128]	validation-rmse:3.44266
# [129]	validation-rmse:3.44266
# [130]	validation-rmse:3.44266
# [131]	validation-rmse:3.44266
# [132]	validation-rmse:3.44266
# [133]	validation-rmse:3.44266
# [134]	validation-rmse:3.44266
# [135]	validation-rmse:3.44266
# [136]	validation-rmse:3.44266
# [137]	validation-rmse:3.44266
# [138]	validation-rmse:3.44266
# [139]	validation-rmse:3.44266
# [140]	validation-rmse:3.44266
# [141]	validation-rmse:3.44266
# [142]	validation-rmse:3.44266
# [143]	validation-rmse:3.44266
# [144]	validation-rmse:3.44266
# [145]	validation-rmse:3.44266

# %%
# Evaluate the model peformance
evaluate_model(loaded_model, X_test, y_test)
# Out:
# (11.851912732286703, 3.4426607053682625)

# %%
# Save the trained model to pickle
with open(f'xgboost.bin', 'wb') as f:
    pickle.dump(loaded_model, f)

# %% [markdown]
# # Calculate predictions using the actual trained model

# %%
# Convert dataframe to DMatrix
data_sequences_df_dmtx = xgb.DMatrix(data_sequences_df[num_features])

# Calculate the predictions
data_sequences_df['prediction']=loaded_model.predict(data_sequences_df_dmtx)
data_sequences_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 5
#       2 data_sequences_df_dmtx = xgb.DMatrix(data_sequences_df[num_features])
#       4 # Calculate the predictions
# ----> 5 data_sequences_df['prediction']=loaded_model.predict(data_sequences_df_dmtx)
#       6 data_sequences_df.head()
#
# NameError: name 'loaded_model' is not defined

# %%
# Testing one sequence prediction
data = [178.369995, 178.779999, 176.449997,	177.710007, 180.259995, 180.789993, 185.580002, 185.369995, 186.860001, 183.419998]

# Reshape data to a 2D array with 1 row and 10 columns
data_dmtx = xgb.DMatrix(pd.DataFrame([data]), feature_names=("d10", "d9", "d8", "d7", "d6", "d5", "d4", "d3", "d2", "d1"))

# Predict using the model
prediction = loaded_model.predict(data_dmtx)

print(prediction)
# Out:
# [178.09828]

# %% [markdown]
# # Calculate predictions loading the "Production" model from S3 bucket

# %%
import mlflow
from mlflow.tracking import MlflowClient


mlflow.set_tracking_uri("http://mlflow:5000")
client = MlflowClient()

model_name = f"stock-goog-xgboost"
stage='production'

# Get the information for the latest version of the model in a given stage
latest_version_info = client.get_latest_versions(model_name, stages=[stage])
latest_stage_version = latest_version_info[0].version
 
# Get the model in the stage
model_stage_uri = f"models:/{model_name}/{latest_stage_version}"
print(f"model_stage_uri: {model_stage_uri}")

# Load model as a PyFuncModel.
model = mlflow.pyfunc.load_model(model_stage_uri)
# Out:
# /tmp/ipykernel_13880/2290926780.py:12: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.12.1/model-registry.html#migrating-from-stages
#   latest_version_info = client.get_latest_versions(model_name, stages=[stage])
# model_stage_uri: models:/stock-goog-xgboost/50
# Downloading artifacts:   0%|          | 0/9 [00:00<?, ?it/s]
# 2024/08/25 21:22:10 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - numpy (current: 1.24.4, required: numpy==1.26.4)
#  - pandas (current: 2.1.1, required: pandas==2.1.4)
#  - psutil (current: 5.9.5, required: psutil==6.0.0)
#  - scikit-learn (current: 1.3.1, required: scikit-learn==1.5.1)
#  - scipy (current: 1.11.3, required: scipy==1.14.0)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# 2024/08/25 21:22:10 WARNING mlflow.pyfunc: The version of Python that the model was saved in, `Python 3.12.4`, differs from the version of Python that is currently running, `Python 3.11.6`, and may be incompatible

# %%
# Calculate the predictions
data_sequences_df['prediction']=model.predict(data_sequences_df[num_features])
data_sequences_df.head()
# Out:
#         date         d10          d9          d8          d7          d6  \
# 0 2024-01-17  139.401367  140.200455  137.883087  137.233841  140.370270
# 1 2024-01-18  140.200455  137.883087  137.233841  140.370270  142.397949
# 2 2024-01-19  137.883087  137.233841  140.370270  142.397949  143.636551
# 3 2024-01-22  137.233841  140.370270  142.397949  143.636551  143.506699
# 4 2024-01-23  140.370270  142.397949  143.636551  143.506699  144.076050
#
#            d5          d4          d3          d2          d1   adj_close  \
# 0  142.397949  143.636551  143.506699  144.076050  143.916229  142.727585
# 1  143.636551  143.506699  144.076050  143.916229  142.727585  144.825195
# 2  143.506699  144.076050  143.916229  142.727585  144.825195  147.801804
# 3  144.076050  143.916229  142.727585  144.825195  147.801804  147.542114
# 4  143.916229  142.727585  144.825195  147.801804  147.542114  148.511002
#
#    prediction
# 0  143.711349
# 1  145.445267
# 2  146.763611
# 3  148.356293
# 4  147.855743

# %%
# Create the dataframe to insert into the stock_prediction table
data_sequences_df['symbol']='goog'
data_sequences_df['model']=model_stage_uri
stockprediction_df = data_sequences_df[['date', 'symbol', 'prediction', 'model']].copy()
stockprediction_df.head()
# Out:
#         date symbol  prediction                          model
# 0 2024-01-17   goog  143.711349  models:/stock-goog-xgboost/50
# 1 2024-01-18   goog  145.445267  models:/stock-goog-xgboost/50
# 2 2024-01-19   goog  146.763611  models:/stock-goog-xgboost/50
# 3 2024-01-22   goog  148.356293  models:/stock-goog-xgboost/50
# 4 2024-01-23   goog  147.855743  models:/stock-goog-xgboost/50

# %%
# Insert historical data into postgres table 'stock_prediction'
stockprediction_df.to_sql('stock_prediction', con=engine, if_exists='append', index=False)
# Out:
# 114

# %% [markdown]
# # Unitary prediction getting data from database

# %%
sequence_length = 10
prediction_date='2024-08-23'
symbol = 'goog'

sql=f"select t.adj_close from (select date, adj_close from stock_ohlc where symbol='{symbol}' and date < '{prediction_date}' order by date desc limit {sequence_length}) t order by t.date asc"
data = pd.read_sql_query(sql,con=engine)

#print(type(data))
#print(data.shape)
#print(data)

#data = np.array(data)
#print(type(data))
#print(data.shape)
#print(data)

# This is the format that We need to use for prediction
data = np.array(data).reshape((1,-1))
print(type(data))
print(data.shape)
print(data)
# Out:
# <class 'numpy.ndarray'>
# (1, 10)
# [[165.38999939 163.94999695 165.92999268 162.02999878 163.16999817
#   164.74000549 168.3999939  168.96000671 167.63000488 165.49000549]]

# %% [markdown]
# # If We are using the actual trained model, convert data list to DMatrix
# data_dmtx = xgb.DMatrix(data, feature_names=("d10", "d9", "d8", "d7", "d6", "d5", "d4", "d3", "d2", "d1"))
# prediction = loaded_model.predict(data_dmtx)[0]
# print(prediction)

# %%
# If We are using the Production model loaded from S3
prediction = model.predict(data)[0]
print(prediction)
# Out:
# 170.82985

# %%
# Insert the new prediction in stock_prediction table
cols = ['date', 'symbol', 'prediction', 'model']
data_all = [prediction_date, symbol, prediction, model_stage_uri]
print(data_all)

df = pd.DataFrame([data_all], columns=cols)
df
# Out:
# ['2024-08-16', 'goog', 178.09828, 'models:/stock-goog-xgboost/2']
#          date symbol  prediction                         model
# 0  2024-08-16   goog  178.098282  models:/stock-goog-xgboost/2

# %%
# Insert unitary prediction into postgres table 'stock_predictions'
df.to_sql('stock_prediction', con=engine, if_exists='append', index=False)
# Out:
# 1
